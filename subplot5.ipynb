# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('planets')
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
plt.bar(df.distance,df.mass)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.xlabel('distance')
plt.ylabel('mass')
plt.title('Graph of planets')
plt.show()

# %%
plt.plot(df.mass,df.distance)

# %%
plt.boxplot(df.year,vert=False);

# %%
plt.scatter(df.mass,df.distance)

# %%
plt.barh(df.orbital_period,df.mass)
# Out:
# <BarContainer object of 1035 artists>

# %%
plt.hist(df.distance)
# plt.show()
# Out:
# (array([753.,  33.,  10.,   4.,   3.,   1.,   0.,   0.,   1.,   3.]),
#  array([1.350000e+00, 8.512150e+02, 1.701080e+03, 2.550945e+03,
#         3.400810e+03, 4.250675e+03, 5.100540e+03, 5.950405e+03,
#         6.800270e+03, 7.650135e+03, 8.500000e+03]),
#  <BarContainer object of 10 artists>)

# %%
name = ['banana','mango','orange','cherry']
price = [200,500,150,150]
plt.pie(price,labels=name)
plt.show()

# %%
fig = plt.figure(figsize =(6, 3))
y = np.array([40,20,25,15])
mylabels=['Apple','Banana','Cherry','Mango']
plt.pie(y,labels=mylabels,shadow=True,explode=[0,.2,.3,.1])
plt.show()
plt.hist(y)
# Out:
# (array([1., 0., 1., 0., 1., 0., 0., 0., 0., 1.]),
#  array([15. , 17.5, 20. , 22.5, 25. , 27.5, 30. , 32.5, 35. , 37.5, 40. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12,8))
plt.subplot(221)
plt.bar(df.mass,df.year,color='cyan')
plt.title('Planet mass vs year')

plt.subplot(222)
plt.boxplot(df.year)
plt.title('Boxplot')

plt.subplot(223)
plt.barh(df.mass,df.distance,color='g')
plt.title('horizontal plot')

plt.subplot(224)
plt.hist(df.year,color='red')
plt.title('histogram')
plt.suptitle('subplot')

plt.tight_layout()
plt.show()
